# %%
from NJmatML import dataML 
import warnings
warnings.filterwarnings("ignore")

# %%
dataML.file_name('Formation energy After.csv') #打开csv并存到data中
# Out:
#             t         μ  A1 NumberofNeutrons  A2 NumberofNeutrons  \
# 0    0.794545  0.398496                    4                    4
# 1    0.893388  0.398496                   12                   12
# 2    1.030247  0.398496                   20                   20
# 3    1.083470  0.398496                   48                   48
# 4    1.140495  0.398496                   78                   78
# ..        ...       ...                  ...                  ...
# 300  0.876552  0.368222                   20                   20
# 301  0.903190  0.327869                   20                   20
# 302  0.879795  0.363178                   20                   20
# 303  0.917125  0.307692                   20                   20
# 304  0.889671  0.348045                   20                   20
#
#      B NumberofNeutrons  A1 SpecificHeat  A2 SpecificHeat  B SpecificHeat  \
# 0                    41            3.582            3.582           0.320
# ...

# %%
dataML.feature_rfe_select1(15)
# Out:
# 特征是否被选中：
#  [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True]
# 获取的数据特征尺寸: (305, 15)
# 最后的特征s_rfe: ['t' 'μ' 'A1 NumberofNeutrons' 'A2 NumberofNeutrons' 'B NumberofNeutrons'
#  'A1 SpecificHeat' 'A2 SpecificHeat' 'B SpecificHeat' 'B Density'
#  'X4 Density' 'B FirstIonization' 'X2 FirstIonization'
#  'X3 FirstIonization' 'B AtomicMass' 'B MeltingPoint']
# 目标target:       Ef (eV)
# 0    5.720877
# 1    3.279887
# 2    3.204452
# 3    2.136704
# 4    0.564954
# ..        ...
# 300 -3.000787
# 301  0.679154
# 302 -0.033382
# 303  0.557565
# 304 -0.530738
#
# [305 rows x 1 columns]
# rfe后的总数据data_rfe:             t         μ  A1 NumberofNeutrons  A2 NumberofNeutrons  \
# 0    0.794545  0.398496                    4                    4
# 1    0.893388  0.398496                   12                   12
# 2    1.030247  0.398496                   20                   20
# 3    1.083470  0.398496                   48                   48
# ...

# %%
dataML.RandomForest_default()
# Out:
# RMSE: 1.3541455451048776
# MAE: 0.9313281151463639
# R2: 0.601747931638472
# MSE: 1.833710157327386
# scores: [0.56178222 0.40217054 0.47955    0.58536236 0.35301551 0.79496888
#  0.90400867 0.71018984 0.83067726 0.5532433 ]
# 1 scores_mean: 0.5617822222840954
# 2 scores_mean: 0.48197638253083547
# 3 scores_mean: 0.48116758863859665
# 4 scores_mean: 0.5072162803551583
# 5 scores_mean: 0.47637612528853335
# 6 scores_mean: 0.5294749171213552
# 7 scores_mean: 0.5829797394043613
# 8 scores_mean: 0.5988810023953067
# 9 scores_mean: 0.6246361426215704
# 10 scores_mean: 0.6174968586329757
# RMSE: 0.47415067648691994
# MAE: 0.3283979176105263
# R2: 0.9568766507388259
# MSE: 0.2248188640130038

# %%
dataML.RandomForest_default()
# Out:
# RMSE: 1.3638179523125713
# MAE: 0.9370751704788314
# R2: 0.5960383335125691
# MSE: 1.8599994070500547
# scores: [0.5634106  0.40111487 0.49883205 0.54735601 0.39743574 0.73811211
#  0.88670709 0.7326613  0.82852442 0.50750884]
# 1 scores_mean: 0.5634106001625465
# 2 scores_mean: 0.4822627374430745
# 3 scores_mean: 0.48778584006748904
# 4 scores_mean: 0.5026783834631537
# 5 scores_mean: 0.48162985543073944
# 6 scores_mean: 0.5243768986863647
# 7 scores_mean: 0.5761383552817613
# 8 scores_mean: 0.5957037236135736
# 9 scores_mean: 0.6215726896822181
# 10 scores_mean: 0.610166304874597
# RMSE: 0.4862839672665253
# MAE: 0.340170229704386
# R2: 0.9546414004604101
# MSE: 0.23647209682047102

# %%
dataML.randomforest_default_predict('Formation energy Predict(1).csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [31], line 1
# ----> 1 dataML.randomforest_default_predict('Formation energy Predict(1).csv')
#
# AttributeError: module 'NJmatML.dataML' has no attribute 'randomforest_default_predict'
